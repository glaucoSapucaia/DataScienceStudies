# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DB_PATH_TREES = 'C:\\Users\\glauc\\OneDrive\\Área de Trabalho\\data_science\\studies\\FormacaoCD\\13.Prática em Python\\dados\\trees.csv'
trees = pd.read_csv(DB_PATH_TREES)
trees.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %% [markdown]
# # Dashboars

# %% [markdown]
# ## Girth and Volume

# %%
plt.scatter(trees.Girth, trees.Volume, color='red')

# %% [markdown]
# ## Girth and Height

# %%
plt.scatter(trees.Girth, trees.Height, color='purple')

# %% [markdown]
# ## Height and Volume

# %%
plt.scatter(trees.Height, trees.Volume, marker='*')

# %% [markdown]
# ## Histogram - Volume

# %%
plt.hist(trees.Volume, bins=6, color='red')
# Out:
# (array([12.,  8.,  5.,  2.,  3.,  1.]),
#  array([10.2       , 21.33333333, 32.46666667, 43.6       , 54.73333333,
#         65.86666667, 77.        ]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# # All plots!

# %%
plt.figure(1)
plt.subplot(2, 2, 1)
plt.scatter(trees.Girth, trees.Volume, color='red')
plt.title('Circunferencia x Volume')
plt.subplot(2, 2, 2)
plt.scatter(trees.Girth, trees.Height, color='purple')
plt.title('Circunferencia x Altura')
plt.subplot(2, 2, 3)
plt.scatter(trees.Height, trees.Volume, marker='*')
plt.title('Altura x Volume')
plt.subplot(2, 2, 4)
plt.hist(trees.Volume, bins=6, color='red')
plt.title('Volume')
plt.tight_layout()

# %% [markdown]
# # Boxplot

# %%
plt.boxplot(trees.Volume, vert=False, showfliers=False, notch=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24d4c2a1700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24d4e519b50>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x24d4c346180>],
#  'medians': [<matplotlib.lines.Line2D at 0x24d4e51a0c0>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# ### Todos os 3 dados numéricos

# %%
plt.boxplot(trees, showfliers=False)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %% [markdown]
# # Dashboard | All boxplots

# %%
plt.boxplot(trees.Volume, vert=False, showfliers=False)
plt.boxplot(trees.Girth, vert=False)
plt.boxplot(trees.Height, vert=False)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %% [markdown]
# # Barras e Setores

# %%
DB_INSECT_PATH = 'C:\\Users\\glauc\\OneDrive\\Área de Trabalho\\data_science\\studies\\FormacaoCD\\13.Prática em Python\\dados\\insect.csv'
insect = pd.read_csv(DB_INSECT_PATH)
insect.describe()
insect.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %% [markdown]
# ## Agrupando dados!

# %%
dados_agrupados = insect.groupby(['spray'])['count'].sum()
dados_agrupados
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
dados_agrupados.plot.bar(color='gray')
# Out:
# <Axes: xlabel='spray'>

# %%
dados_agrupados.plot.bar(color=['red', 'yellow', 'black', 'blue', 'orange', 'purple'])
# Out:
# <Axes: xlabel='spray'>

# %%
dados_agrupados.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
dados_agrupados.plot.pie(legend=True)
# Out:
# <Axes: ylabel='count'>
