# %% [markdown]
# # New lib
# ### from mpl_toolkits.mplot3d import axes3d

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as plt3d

DB_ORCHARD_PATH = 'C:\\Users\\glauc\\OneDrive\\Área de Trabalho\\data_science\\studies\\FormacaoCD\\13.Prática em Python\\dados\\orchard.csv'
orchard = pd.read_csv(DB_ORCHARD_PATH)
orchard
# Out:
#     decrease  rowpos  colpos treatment
# 0         57       1       1         D
# 1         95       2       1         E
# 2          8       3       1         B
# 3         69       4       1         H
# 4         92       5       1         G
# ..       ...     ...     ...       ...
# 59        14       4       8         B
# 60        86       5       8         H
# 61        55       6       8         E
# 62         3       7       8         A
# 63        19       8       8         C
#
# [64 rows x 4 columns]

# %%
figure_ = plt.figure()
ax = figure_.add_subplot(1, 1, 1, projection="3d")
ax.scatter(orchard.decrease, orchard.rowpos, orchard.colpos)
ax.set_xlabel('decrease')
ax.set_ylabel('rowpos')
# Out:
# Text(0.5, 0.5, 'rowpos')
