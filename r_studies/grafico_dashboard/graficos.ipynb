# %%
trees
# Out:
#    Girth Height Volume
# 1   8.3  70     10.3
# 2   8.6  65     10.3
# 3   8.8  63     10.2
# 4  10.5  72     16.4
# 5  10.7  81     18.8
# 6  10.8  83     19.7
# 7  11.0  66     15.6
# 8  11.0  75     18.2
# 9  11.1  80     22.6
# 10 11.2  75     19.9
# 11 11.3  79     24.2
# 12 11.4  76     21.0
# 13 11.4  76     21.4
# 14 11.7  69     21.3
# 15 12.0  75     19.1
# 16 12.9  74     22.2
# 17 12.9  85     33.8
# 18 13.3  86     27.4
# 19 13.7  71     25.7
# 20 13.8  64     24.9
# 21 14.0  78     34.5
# 22 14.2  80     31.7
# 23 14.5  74     36.3
# 24 16.0  72     38.3
# 25 16.3  77     42.6
# 26 17.3  81     55.4
# 27 17.5  82     55.7
# 28 17.9  80     58.3
# 29 18.0  80     51.5
# 30 18.0  80     51.0
# 31 20.6  87     77.0

# %% [markdown]
# # Histograma

# %%
hist(trees$Height)
# Out:
# Plot with title "Histogram of trees$Height"

# %%
hist(trees$Height, main='Árvores', ylab = 'Frequência', xlab = 'Altura', col='blue')
# Out:
# Plot with title "Árvores"

# %%
hist(
    trees$Height, main='Árvores', ylab = 'Frequência', xlab = 'Altura',
    col='gray', density=20, breaks=20
)
# Out:
# Plot with title "Árvores"

# %%
densidade = density(trees$Height)
plot(densidade)
# Out:
# Plot with title "density(x = trees$Height)"

# %% [markdown]
# # Sobreposição Histogramas

# %%
hist(trees$Height, main=NULL, xlab = NULL, ylab = NULL)
par(new=T)
plot(densidade)
# Out:
# Plot with title "density(x = trees$Height)"

# %% [markdown]
# # Fluxogramas

# %%
plot(
    trees$Girth, trees$Volume, main='Árvores', ylab='Circunferencia',
    xlab='Volume', col='blue', pch=19
)
plot(
    trees$Girth, trees$Volume, main='Árvores', ylab='Circunferencia',
    xlab='Volume', col='blue', pch=19, type='l'
)
# Out:
# Plot with title "Árvores"
# Plot with title "Árvores"

# %%
plot(jitter(trees$Girth), trees$Volume, main="Árvores", ylab='Circunferencia', xlab='Volume',
col='blue', pch=19)
# Out:
# Plot with title "Árvores"

# %% [markdown]
# # Legendas

# %%
CO2
plot(CO2$conc, CO2$uptake, pch=20, col=(CO2$Treatment))
legend('bottomright', legend=c('nonchilled', 'chilled'), cex=1, fill=c('black', 'red'))
# Out:
#    Plant Type        Treatment  conc uptake
# 1  Qn1   Quebec      nonchilled   95 16.0
# 2  Qn1   Quebec      nonchilled  175 30.4
# 3  Qn1   Quebec      nonchilled  250 34.8
# 4  Qn1   Quebec      nonchilled  350 37.2
# 5  Qn1   Quebec      nonchilled  500 35.3
# 6  Qn1   Quebec      nonchilled  675 39.2
# 7  Qn1   Quebec      nonchilled 1000 39.7
# 8  Qn2   Quebec      nonchilled   95 13.6
# 9  Qn2   Quebec      nonchilled  175 27.3
# 10 Qn2   Quebec      nonchilled  250 37.1
# 11 Qn2   Quebec      nonchilled  350 41.8
# 12 Qn2   Quebec      nonchilled  500 40.6
# 13 Qn2   Quebec      nonchilled  675 41.4
# 14 Qn2   Quebec      nonchilled 1000 44.3
# 15 Qn3   Quebec      nonchilled   95 16.2
# 16 Qn3   Quebec      nonchilled  175 32.4
# 17 Qn3   Quebec      nonchilled  250 40.3
# 18 Qn3   Quebec      nonchilled  350 42.1
# 19 Qn3   Quebec      nonchilled  500 42.9
# 20 Qn3   Quebec      nonchilled  675 43.9
# 21 Qn3   Quebec      nonchilled 1000 45.5
# ...

# %% [markdown]
# # Matrizes de gráficos

# %%
plot(trees)
# Out:
# plot without title

# %%
split.screen(figs = c(2, 2))
screen(1)
plot(trees$Girth, trees$Height)
screen(2)
plot(trees$Girth, trees$Volume)
screen(3)
plot(trees$Volume, trees$Height)
screen(4)
hist(trees$Volume)
close.screen(all=T)
# Out:
# [1] 1 2 3 4
# Plot with title "Histogram of trees$Volume"
