# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dados/trees.csv')
data.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %% [markdown]
# ## Figuras

# %%
plt.figure(1, layout='constrained')
plt.subplot(2, 2, 1)
plt.scatter(data.Girth, data.Height)
plt.title('Árvores')
plt.xlabel('Circunferência')
plt.ylabel('Altura')
plt.subplot(2, 2, 2)
plt.scatter(data.Girth, data.Volume)
plt.title('Árvores')
plt.xlabel('Circunferência')
plt.ylabel('Volume')
plt.subplot(2, 2, 3)
plt.scatter(data.Volume, data.Height)
plt.title('Árvores')
plt.xlabel('Volume')
plt.ylabel('Altura')
plt.subplot(2, 2, 4)
plt.plot(data.Volume)
plt.title('Árvores | Volume')
# Out:
# Text(0.5, 1.0, 'Árvores | Volume')
