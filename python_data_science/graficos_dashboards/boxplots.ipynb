# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dados/trees.csv')
data.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(data.Volume, vert=False, notch=True, showfliers=False,
            patch_artist=True)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(data, vert=True, patch_artist=True, showfliers=True)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %% [markdown]
# ## Seaborn | Boxplot

# %%
sns.boxplot(data=data.Volume, orient='h').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >
